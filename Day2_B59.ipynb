# %%
understanding the variables in python

# %%
x = 2
y = 3

# %%
z = x+y

print(z)
# Out:
# 5

# %%
 Rules for declaring the variables in python

# %%
Rule No : 1 - No Namespaces while declaring the variables

# %%
first name = 'Faiyaz'

print(first name)
# Out:
#   File "<ipython-input-3-1cbbde1ec4db>", line 1
#     first name = 'Faiyaz'
#           ^
# SyntaxError: invalid syntax

# %%
firstname = "Faiyaz"
print(firstname)
# Out:
# Faiyaz

# %%
Rule No 2 : A variable name should not start with a number **

# %%
1name = 'kumar'

print(1name)
# Out:
#   File "<ipython-input-5-c0ed3150f447>", line 1
#     1name = 'kumar'
#      ^
# SyntaxError: invalid syntax

# %%
name1 = 'kumar'

print(name1)
# Out:
# kumar

# %%
Rule No 3 : A variable name should not contain any special characters
    
    @$%&

# %%
name@ = 'naveen'

print(name@)
# Out:
#   File "<ipython-input-7-53b374a526fb>", line 1
#     name@ = 'naveen'
#           ^
# SyntaxError: invalid syntax

# %%
for executing the cells we have to press Shift + enter button....

# %%
introduction to datatypes in python :
    
    1. String   --- str
    
    2. Number ---- integers (int)and floats ( float) ( decimal)
    
    3. lists ----> list
    
    4. tuples ----> tuple
    
    5. Dictionaries ---- dict

# %%
classification of datatypes in python :
    
    1. Mutable  -----> which we can edit and alter   ======> flexible in nature
    
    2. immutable -----> which we cannot able to edit or alter ====> fixed in Nature

# %%
introduction to string datatype :
    
    
Defination : A string is a series of characters declared in quotes.
    
classification : it is classified as an immutable datatype
    
how to declare the string datatype....?

3 approaches of declaring the string.

1. single quote

2. double quote

3. triple quote.

# %%
name1 = 'ravi'   # single quote

print(name1)
# Out:
# ravi

# %%
name2 = "john"  # double quote

print(name2)
# Out:
# john

# %%
name3 = """keerthi"""  # triple quote

print(name3)
# Out:
# keerthi
