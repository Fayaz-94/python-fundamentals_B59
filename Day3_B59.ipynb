# %%
continuation with strings :

# %%
introduction to string methods :

# %%
name = 'kumar'

print(name)
# Out:
# kumar

# %%
type(name)
# Out:
# str

# %%
string ----> str

# %%
name1 = "naveed"

print(name1)
# Out:
# naveed

# %%
type(name1)
# Out:
# str

# %%
fullname = 'rajesh kumar'

print(fullname)
# Out:
# rajesh kumar

# %%
print(fullname.title())
# Out:
# Rajesh Kumar

# %%
# req : i want to get the fullname in capital letters....?

# %%
print(fullname.upper())
# Out:
# RAJESH KUMAR

# %%
#  req : i want to get the fullname in smallcase letters...?

# %%
print(fullname.lower())
# Out:
# rajesh kumar

# %%
introduction to f strings :

# %%
# genral syntax for the f strings :

# %%
f" custom message {placeholder1} {placeholder2}.....{placeholder....n}"

# %%
firstname = 'vamsi'
lastname = 'chowdhry'

# %%
# req : get the full name ....?

# %%
full_name = f"{firstname} {lastname}"

print(full_name)
# Out:
# vamsi chowdhry

# %%
print(full_name.title())
# Out:
# Vamsi Chowdhry

# %%
message = f"keep up the good work, {full_name.title()}"

print(message)
# Out:
# keep up the good work, Vamsi Chowdhry

# %%
Adding whitespaces to strings :

# %%
print('favourite_language:pythonC++javacpascalcobal')
# Out:
# favourite_language:pythonC++javacpascalcobal

# %%
print('favourite_language:\npython\nC++\njava\nc\npascal\ncobal')
# Out:
# favourite_language:
# python
# C++
# java
# c
# pascal
# cobal

# %%
\n -----> new line delimiter

# %%
print('favourite_language:\n\tpython\n\tC++\n\tjava\n\tc\n\tpascal\n\tcobal')
# Out:
# favourite_language:
# 	python
# 	C++
# 	java
# 	c
# 	pascal
# 	cobal

# %%
\t ----> tab delimiter
